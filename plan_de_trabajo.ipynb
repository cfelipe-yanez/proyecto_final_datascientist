# %% [markdown]
# # Hola &#x1F600;,
#
# Soy **Hesus Garcia** – **"Soy el único Hesus que conoces (y probablemente conocerás) 🌟"** – Sí, como "Jesús", pero con una H que me hace único. Puede sonar raro, pero créeme, ¡no lo olvidarás! Como tu revisor en Triple-Ten, estoy aquí para guiarte y ayudarte a mejorar tu código. Si algo necesita un ajuste, no hay de qué preocuparse; ¡aquí estoy para hacer que tu trabajo brille con todo su potencial! ✨
#
# Cada vez que encuentre un detalle importante en tu código, te lo señalaré para que puedas corregirlo y así te prepares para un ambiente de trabajo real, donde el líder de tu equipo actuaría de manera similar. Si en algún momento no logras solucionar el problema, te daré más detalles para ayudarte en nuestra próxima oportunidad de revisión.
#
# Es importante que cuando encuentres un comentario, **no los muevas, no los modifiques, ni los borres**.
#
# ---
#
# ### Formato de Comentarios
#
# Revisaré cuidadosamente cada implementación en tu notebook para asegurar que cumpla con los requisitos y te daré comentarios de acuerdo al siguiente formato:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> - ¡Excelente trabajo! Esta parte está bien implementada y contribuye significativamente al análisis de datos o al proyecto. Continúa aplicando estas buenas prácticas en futuras secciones.
#
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Atención</b> ⚠️ - Este código está correcto, pero se puede optimizar. Considera implementar mejoras para que sea más eficiente y fácil de leer. Esto fortalecerá la calidad de tu proyecto.
#
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>A resolver</b> ❗ - Aquí hay un problema o error en el código que es necesario corregir para aprobar esta sección. Por favor, revisa y corrige este punto, ya que es fundamental para la validez del análisis y la precisión de los resultados.
#
# </div>
#
# ---
#
# Al final de cada revisión, recibirás un **Comentario General del Revisor** que incluirá:
#
# - **Aspectos positivos:** Un resumen de los puntos fuertes de tu proyecto.
# - **Áreas de mejora:** Sugerencias sobre aspectos donde puedes mejorar.
# - **Temas adicionales para investigar:** Ideas de temas opcionales que puedes explorar por tu cuenta para desarrollar aún más tus habilidades.
#
# Estos temas adicionales no son obligatorios en esta etapa, pero pueden serte útiles para profundizar en el futuro.
#
# ---
#
#
# Esta estructura en viñetas facilita la lectura y comprensión de cada parte del comentario final.
#
# También puedes responderme de la siguiente manera si tienes alguna duda o quieres aclarar algo específico:
#
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Aquí puedes escribir tu respuesta o pregunta sobre el comentario.
#
# </div>
#
#
# **¡Empecemos!** &#x1F680;

# %%
import pandas as pd
df_contract = pd.read_csv('/datasets/final_provider/contract.csv')
df_personal = pd.read_csv('/datasets/final_provider/personal.csv')
df_internet = pd.read_csv('/datasets/final_provider/internet.csv')
df_phone = pd.read_csv('/datasets/final_provider/phone.csv')

# %% [markdown]
# <div class="alert alert-block alert-warning"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Atención</b> ⚠️ - Buen inicio cargando los cuatro datasets desde el principio. Una pequeña mejora que podrías considerar es asegurarte de que las celdas se ejecuten en orden secuencial (las que aparecen con número entre corchetes), porque si ejecutas “saltado” puedes terminar mezclando versiones parciales de dataframes y obtener resultados inconsistentes. Esto fortalecerá la reproducibilidad de tu notebook y hará tu análisis más confiable. ¡Sigue así, estás en buen camino!
#
# </div>

# %%
df_contract.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   BeginDate         7043 non-null   object
#  2   EndDate           7043 non-null   object
#  3   Type              7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   float64
#  7   TotalCharges      7043 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 440.3+ KB

# %%
df_personal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   object
#  1   gender         7043 non-null   object
#  2   SeniorCitizen  7043 non-null   int64
#  3   Partner        7043 non-null   object
#  4   Dependents     7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %%
df_internet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5517 entries, 0 to 5516
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        5517 non-null   object
#  1   InternetService   5517 non-null   object
#  2   OnlineSecurity    5517 non-null   object
#  3   OnlineBackup      5517 non-null   object
#  4   DeviceProtection  5517 non-null   object
#  5   TechSupport       5517 non-null   object
#  6   StreamingTV       5517 non-null   object
#  7   StreamingMovies   5517 non-null   object
# dtypes: object(8)
# memory usage: 344.9+ KB

# %%
df_phone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6361 entries, 0 to 6360
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     6361 non-null   object
#  1   MultipleLines  6361 non-null   object
# dtypes: object(2)
# memory usage: 99.5+ KB

# %% [markdown]
# # Plan de trabajo

# %% [markdown]
# ## Una lista de preguntas aclaratorias que quieras discutir con tu líder de equipo.

# %% [markdown]
# ¿Cuál es el objetivo principal desde el punto de vista del negocio: identificar a los clientes con mayor probabilidad de cancelar o entender qué factores influyen más en la cancelación?
#
# ¿El enfoque del proyecto debe priorizar máximo desempeño del modelo o un balance entre desempeño e interpretabilidad para el equipo de marketing?
#
# ¿Cómo se espera que el equipo de marketing utilice el resultado del modelo en la práctica (por ejemplo, alertas tempranas, segmentación de clientes, campañas específicas)?
#
# ¿Existe algún criterio de negocio adicional (como costos de retención o límites de promociones) que deba considerarse al evaluar el modelo?
#
# ¿Hay alguna suposición o restricción conocida sobre los datos que deba tenerse en cuenta antes del análisis?

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# Entiendo por qué lo preguntas así, pero es importante ajustar el enfoque: este tipo de empresa se parece a muchas organizaciones que están implementando su **primer** proyecto de ciencia de datos. Eso significa que, en la práctica, **no existe todavía una respuesta “oficial”** para estas preguntas (objetivo exacto, umbrales, cómo lo usará marketing, etc.). Por eso tu plan no debe quedarse “a la espera”, sino que debe **proponer** una primera versión razonable, explicar por qué, y dejar claro qué se validará con el equipo antes de programar.
#
#
# 1. <b>¿Cuál es el objetivo principal desde el punto de vista del negocio?</b><br>
#    En un primer proyecto, lo más común es que el negocio diga “queremos reducir churn” pero sin decidir si prefiere explicación o predicción. Tu plan debe proponer un objetivo principal y un objetivo secundario:
#
# * Propuesta de objetivo principal: <b>entender los factores que influyen en la cancelación</b> para poder diseñar acciones claras (qué cambiar, qué ofrecer, a quién segmentar).
# * Propuesta de objetivo secundario: <b>generar una lista priorizada</b> de clientes con mayor probabilidad de cancelar para iniciar contacto o campañas.<br>
#   Por qué es importante: si no defines esto, después no sabrás si estás optimizando “explicación” o “ranking”, y eso cambia métricas, modelos y el tipo de entregable.
#
# 2. <b>¿El enfoque debe priorizar máximo desempeño o un balance con interpretabilidad?</b><br>
#    Como es el primer proyecto y el equipo no es técnico, el riesgo más grande no es la calidad del AUC, sino que el modelo no se use por falta de confianza o que no se entiende.
#
# * Propuesta inicial: <b>priorizar interpretabilidad</b> y exigir un desempeño “suficiente” para ser útil, en vez de buscar el máximo posible.
# * Qué debes dejar escrito: qué significa interpretabilidad para ti en este caso, por ejemplo:
#
#   * explicaciones globales: cuáles variables empujan churn hacia arriba/abajo,
#   * explicaciones por cliente: por qué un cliente aparece en el top de riesgo,
#   * un resumen en lenguaje de negocio, no solo métricas técnicas.<br>
#     Por qué es importante: si marketing no entiende el “por qué”, no actúa, y el proyecto se queda en un score sin impacto.
#
# 3. <b>¿Cómo se espera que marketing utilice el resultado del modelo?</b><br>
#    En un primer proyecto normalmente “no se sabe” el uso exacto. Ahí tu papel es proponer un uso operativo simple y medible. En tu plan, plantea 2 o 3 usos posibles y recomienda uno como punto de partida.
#
# * Propuesta de uso 1 (operativo y simple): <b>ranking periódico</b> de clientes de mayor riesgo para contacto proactivo (top N por semana/mes).
# * Propuesta de uso 2 (más estratégico): <b>segmentación por factores</b>, campañas distintas según el principal motivo de riesgo (contrato, método de pago, servicios).
#
#   Qué debes dejar definido en el plan: el formato del entregable (tabla con score y razones), la periodicidad y quién lo recibe. Aunque sea una propuesta inicial, debe ser concreta para que el proyecto tenga “modo de uso” desde el día 1.
#
# 4. <b>¿Existe algún criterio de negocio adicional?</b><br>
#    Aquí tú ya sabes que no hay criterios adicionales porque están explorando. Aun así, el plan debe evitar que todo quede “sin reglas”.
#
# * Respuesta en el plan: <b>no existen criterios adicionales definidos por el negocio en esta fase</b>.
# * Propuesta mínima que tú debes incluir: un criterio operativo para poder elegir umbrales, por ejemplo:
#
#   * capacidad de contacto (cuántos clientes puede atender marketing por periodo),
#   * tolerancia a falsos positivos (cuántos “clientes que no iban a cancelar” aceptan contactar),
#
#     Por qué es importante: sin esto, puedes terminar con un modelo que “funciona” pero entrega una lista de 3,000 clientes cuando marketing solo puede atender 200.
#
# 5. <b>¿Hay alguna suposición o restricción conocida sobre los datos?</b><br>
#    En proyectos nuevos normalmente no hay restricciones documentadas, pero tu plan debe listar lo que vas a verificar sí o sí antes de modelar.
#
# * Respuesta en el plan: <b>no hay restricciones conocidas a priori</b>, por lo que se harán validaciones de calidad y consistencia.
# * Suposiciones/validaciones mínimas que debes incluir:
#
#   * definición exacta de la etiqueta de churn y confirmación de que se puede construir con los datos,
#   * evitar fuga de información (no usar columnas que “delaten” cancelación),
#   * estrategia de merges para no perder clientes al unir tablas con menos filas,
#   * limpieza de tipos (por ejemplo variables numéricas guardadas como texto),
#   * y que el notebook se ejecute en orden secuencial (celdas numeradas en corchetes) sin errores para garantizar reproducibilidad.<br>
#     Por qué es importante: estas validaciones son las que separan un plan “bonito” de un plan que realmente se puede ejecutar sin sorpresas.
#
# En lugar de presentar estas preguntas como “algo que la empresa debe responderte”, preséntalas como “puntos que aún no están definidos porque es el primer proyecto”
#
# </div>

# %% [markdown]
# ## Un plan aproximado para resolver la tarea

# %% [markdown]
# 1. <u>Carga y unificación de datos:</u>
# Importar los cuatro conjuntos de datos y unirlos mediante la columna customerID, verificando la consistencia del número de registros y la integridad de la información tras la fusión.
#
# 2. <u>Análisis exploratorio de datos (EDA):</u>
# Analizar la distribución de la variable objetivo, identificar posibles valores ausentes, detectar desbalances de clase y explorar relaciones preliminares entre características del contrato, servicios y cancelación.
#
# 3. <u>Preprocesamiento y preparación de datos:</u>
# Convertir la variable objetivo a formato binario, codificar variables categóricas, tratar valores faltantes y escalar variables numéricas cuando sea necesario para el entrenamiento de modelos.
#
# 4. <u>Entrenamiento y evaluación de modelos:</u>
# Entrenar uno o más modelos de clasificación, evaluar su desempeño usando AUC-ROC como métrica principal y exactitud como métrica complementaria, y comparar resultados para seleccionar el mejor enfoque.
#
# 5. <u>Análisis de resultados y conclusiones:</u>
# Interpretar el desempeño del modelo seleccionado, evaluar su utilidad práctica para el equipo de marketing y concluir si la visión artificial y el aprendizaje automático pueden ayudar a reducir la tasa de cancelación.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Atención</b> ⚠️ - Tu plan está bien encaminado y tiene una secuencia lógica clara (datos, EDA, preprocesamiento, modelado, conclusiones). Para que cumpla un estándar “versión completa” y sea realmente útil como guía de trabajo, te conviene volverlo más específico desde el inicio, pero ojo, todavía no lo implementes: primero déjalo bien definido en texto. Esto es importante porque un plan detallado evita que el proyecto se evalúe con criterios ambiguos, reduce retrabajo y hace que tus resultados sean defendibles frente a stakeholders.
#
# Para aterrizarlo, agrega (solo en el plan) definiciones concretas como estas:
#
# * **Problema, objetivo y variable objetivo:** ¿cómo reformulas el problema de churn con tus palabras y qué valor de negocio esperas?, ¿cuál es exactamente la variable objetivo y cómo se construye con estos archivos (por ejemplo si “canceló” se deriva de <code>EndDate</code>)?, ¿qué será llave y no feature (como <code>customerID</code>)?
# * **Mapa de variables (categorías y numéricas):** enumera cuáles variables son categóricas (por ejemplo <code>Type</code>, <code>PaperlessBilling</code>, <code>PaymentMethod</code>, <code>InternetService</code>, servicios de seguridad/soporte/streaming, <code>MultipleLines</code>) y cuáles numéricas (por ejemplo <code>MonthlyCharges</code> y cómo limpiarás <code>TotalCharges</code> que hoy está como texto). Esto importa porque algunos modelos requieren codificación y escalado, y otros son más robustos a ese preprocesamiento.
# * **Hipótesis y KPIs medibles:** plantea al menos 3 hipótesis con estructura **H0/H1** y asócialas a KPIs con fórmula (por ejemplo tasa de churn total, churn por tipo de contrato, churn por método de pago, churn por servicios). Define también umbrales esperados para que “éxito” no sea subjetivo.
# * **Modelos, cantidad y razón de elección:** en lugar de “uno o más”, especifica cuántos modelos como mínimo compararás y cuáles, separando al menos un baseline interpretable y otro orientado a desempeño. Explica por qué: algunos modelos funcionan mejor con muchas categóricas e interacciones no lineales, mientras que otros son más fáciles de explicar al equipo de marketing.
#
# Y un recordatorio clave del entregable: asegúrate de que el notebook se ejecute **en orden secuencial** (celdas numeradas en corchetes) sin errores. Esto es importante porque garantiza reproducibilidad y evita resultados inconsistentes por ejecutar celdas “saltadas”.
#
#
# </div>
